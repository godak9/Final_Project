# %%
# For output clarity 
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np 
import re

# %%
#Importing clearn sharks data--rows confirmed attack 
# From kaggle https://www.kaggle.com/datasets/thedevastator/shark-attacks-the-risks-of-coastal-water-activit
# FromShark Research Institute's website https://www.sharkattackfile.net/incidentlog.htm
file_path = "shark_bite_confirmed.csv"
confirmed_attack_df = pd.read_csv(file_path)
confirmed_attack_df.columns
# Out:
# Index(['index', 'Case Number', 'Date', 'Year', 'Type', 'Country', 'Area',
#        'Location', 'Activity', 'Name', 'Unnamed: 9', 'Age', 'Injury',
#        'Fatal (Y/N)', 'Time', 'Species'],
#       dtype='object')

# %%
# Rename "Sex" column 
confirmed_attack_df.rename(columns = {'Unnamed: 9': 'Sex'}, inplace = True)
confirmed_attack_df.columns
confirmed_attack_copy = confirmed_attack_df.copy()

# %%
# Check values in "Sex" column
#list(confirmed_attack_copy.Sex.unique())

# %%
# Check values in "Name" column--a lot of individuals' sex is stated in this column
#list(confirmed_attack_copy.Name.unique())

# %%
# Make a copy if you mess up 
# Good thing becasue I did mess up... 
# "Name" will be renamed to "People Involved" at the end--either "I" for individual "M" for multiple of "U" for unknown
# Retaining name column, making it "Name2", will be renamed "Name" at the end
# "Name2" will be renamed "Name" at the end
# At the end of labeling I will create a new CSV with on the "Case Number" (unqiue value for connecting tables) "Sex", 
#"Number of Victims", "Name"

# In the database this will be called the "Victimology" table
# Importing with necessary columns
columns = [
    'Case Number',
    'Name',
    'Sex',
]
confirmed_attack_copy2 = confirmed_attack_copy.loc[:, columns]
#confirmed_attack_copy2
confirmed_attack_copy2['Name2'] = confirmed_attack_copy2.loc[:, 'Name']
confirmed_attack_copy2
# Out:
#        Case Number                   Name  Sex                  Name2
# 0       2020.02.05                    NaN  NaN                    NaN
# 1     2020.01.30.R        Ana Bruna Avila    F        Ana Bruna Avila
# 2       2020.01.17         Will Schroeter    M         Will Schroeter
# 3       2020.01.16            Jordan King    F            Jordan King
# 4       2020.01.13           Samuel Horne    M           Samuel Horne
# ...            ...                    ...  ...                    ...
# 5930       ND.0005                   male  NaN                   male
# 5931       ND.0004                  Ahmun  NaN                  Ahmun
# 5932       ND.0003  Coast Guard personnel  NaN  Coast Guard personnel
# 5933       ND.0002        Jules Patterson  NaN        Jules Patterson
# 5934       ND.0001                   male  NaN                   male
#
# [5935 rows x 4 columns]

# %%
# The "Sex" column will have the values "M" for male, "F" for female, "U" for unknown, or "S" for several.
# The columns with "S" values will be used to pinpoint the rows we need to isolate and fill in the new columns manually 
# If value is nan in the "Name" column, make "Sex" value "U"--Meaning Unknown
confirmed_attack_copy2['Name'].fillna('Unknown', inplace = True)

# %%
# If the word "female" is in "Name", change "Sex" to "F"--Meaning Female
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bfemale\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bFemale\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bwoman\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bMrs\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bgirl\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bEmmanuelle\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bErica\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bMaggie\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bEmily\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bMelissa\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bJackie\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bPaige\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bKimberly\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bIsabella\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bSue\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bKara\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bLola\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bLaura\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bKatarina\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bJulie\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bMelisa\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bEmily\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bAnna\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bSharna\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bMarjorie\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bNatalie\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bSarah\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bKaia\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bSusan\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bCatherine\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bViolet\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bKirstenb', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bOlivia\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bZoe\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bCarly\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bTiffany\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bMackenzie\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bLeeanne\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bHolly\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bLaeticia\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bDenise\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bHeather\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bMelanie\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bCaitlyn\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bBarbara\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bJade\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bDoreen\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bMaria\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bMary\b', case = 'false'), 'Sex'] = 'F'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\b
 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'J. McCorley', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'J. L Pérez-Díaz', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'J. Jordaan', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'Oaulkurt-Pape', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'M. Worman', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'C. Thackwray', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'R. Bartlett', 'Sex'] = 'M'

confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'D. Trayling', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'G. Byron', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'K. Tracy', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'J. Horner', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'D.R. McGinnis', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'D.C. Barnes', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'J. Gillies', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'W.D. Simpson', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'H. Meacham', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'R. Vidler', 'Sex'] = 'M'

confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'A.W.F. Patterson', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'W. A. Strijdom', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'W.W. Fitzsimmons', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'B. May', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'W.T. Luxton', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'I. Padden', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'Marik-Pokas', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'P. Wagener', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'Souleymane S.', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'R.P. Straughan', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'B. Irving', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'Tuisafua Nomoa', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'R.P.L. Straughan', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'R. Nauth', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'Bansie Koide', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'R.C. Olsen', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'A.J. Eggink', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'R. Palmer, ship’s apprentice', 'Sex'] = 'M'

confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'Metuela Mau', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'A.S. Festing', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == "14' catamaran, occupant: M. Leverenz", 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'E. J. McHugh', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'British constable', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'E.W. Bilton', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'E.F. MacEwan', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'T. S. Ramsbottom', 'Sex'] = 'M'

confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'A. Arvanitakis', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'Racing scull, occupant: C.E. Slaughter, Queensland sculling champion', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'Guisne Oscoto (Japanese)', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'C.E. Slaughter', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'British constable', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'A. R. Davis', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'W. McCann', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'D. Bennett', 'Sex'] = 'M'

confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'A. Ewen', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'A.B. Wattigney', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] =='F.P. Jones', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'L. Aldridge', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'W.R. Loesberg', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == "N'gena Zakali", 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'Bosun of the ship', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'T.F. Davies', 'Sex'] = 'M'

confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'J.L. Hanscomb', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'M.F. Turnipseed', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'A. Steinstecke', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'H. McGregor', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'J. Richardson', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == "Seaman Gray", 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == '"Hoke" Smith', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'Somali boatman', 'Sex'] = 'M'

confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'E. Reynolds', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'J.B. Johnston', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'A.Y. Glyde', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'H. Cook', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'Private Dunn', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == "Minor Hodgdon", 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == '"Hoke" Smith', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == '"The Queen\'s Chaplain"', 'Sex'] = 'M'

confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'A candidate for initiation', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'C.D. Dollar', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == "crewman from the Gedi", 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == "Ham, a Cambodian migrant worker", 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == "a father of six", 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'boat of Wally Gibbons', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == '18 hp Boston Whaler boat, occupant: G. W. Bane, Jr.'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'boat, occupant: R. Southey of Lautoka', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bThierry\b', case = 'false'), 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bHaumole\b', case = 'false'), 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bYoshihiro\b', case = 'false'), 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'Crewman of Taiwanese tuna boat Sin Shih Ki II', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == '15-foot boat: occupant Woodrow Smith', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == "16' boat, occupant: W. Lonergan", 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'Leopoldo Sanchez, a messboy from the ship MV Maripaz', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == "W. Davidson", 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == "O'Leary, a Torres Strait islander", 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bManduray\b', case = 'false'), 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bJanardhan\b', case = 'false'), 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == "12' skiff, occupant: E.R.F. Johnson", 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bTala\b', case = 'false'), 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'Barani, a Papuan', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'A dinghy, occupant J.W. Wall', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'Bili, a Papuan', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'Kosam, a Torres Strait Islander', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'Tumia, a Torres Strait Islander', 'Sex'] = 'M'

confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'Ibigan, a Torres Strait islander', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'Ned Luffman, a Torres Strait Islander', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'Wanewa, a Torres Strait Islander', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'Quassa, a Torres Strait Islander', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'Treacle, a Torres Strait islander', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'Dahkus, a Molussa Moro', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'E.J. Sharpe', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'a Frenchman', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'H. Gebler', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'skipper of a coasting schooner', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'a fireman from the Ettrickdale', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'a deserter from the ship Evarest', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'a boat steerer', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == "a ship's steward", 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'Sutto Cumar Mukerjea, a.k.a. Haboo', 'Sex'] = 'M'

confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'B., "an Ooryah coolie"', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'H.E.S., a Hindu trader', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'cook from the Charleston', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == '"a lad"', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'a deserter from the U.S. Pennsylvania', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == "a ship's engineer", 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'a young Scotsman', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == "a chief", 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == "boat, occupant: Portuondo", 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == "Albertus, a Malay", 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == "Professor Winslow", 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == "Omni (rescuer)", 'Sex'] = 'M'

confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'Dr. D.H. Teas', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'Dr. H. Warmke', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'a dock worker', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'second cook', 'Sex'] = 'M'
#Change "Name" column to "M"-mulitple or "I"-individual 
confirmed_attack_copy2.loc[(confirmed_attack_copy2["Sex"] == 'M'), "Name"] = 'I'

# %%
# If values in the "Name" column indicated multiple people, change "Sex" to "S"-- Meaning Several
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'&', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\band\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\boccupants\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bx\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bpoachers\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bmigrants\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bcrewmen\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\b4\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\brefugees\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bmales\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bpeople\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bmen\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bswimmers\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bmarines\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bsoldiers\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bpirates\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bslaves\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bIslanders\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\b5\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bGonFishin\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bSinking\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\byouths\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bHI-2\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == "boat of Scot's College rowers", 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bbrothers\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bboats\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bfishermen\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\btourists\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bwomen\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\b23\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\btourists\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\baviators\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bincidents\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bfliers\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bdays\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bNegros\b', case = 'false'), 'Sex'] = 'S'

confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bpersonnel\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bsailors\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bMarines\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bcrew\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bpilgrims\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bparty\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bseamen\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bairmen\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bdivers\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bFijians\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bchildren\b', case = 'false'), 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == "Japanese seamen", 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == "rowboats attacked by sharks", 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == "multiple bathers", 'Sex'] = 'S'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == "Fishermen", 'Sex'] = 'S'
#several_victims_df = confirmed_attack_copy2[(confirmed_attack_copy2["Sex"] == 'S')]

# Change "Name" column to "M"-mulitple or "I"-individual 
confirmed_attack_copy2.loc[confirmed_attack_copy2['Sex'] == 'S', 'Name'] = 'M'

# %%
# Changing all lables now "M" "F" or "S" to "U" for "Unknown"
confirmed_attack_copy2.loc[confirmed_attack_copy2['Sex'] == 'Unknown', 'Sex'] = 'U'
sex_labels = ['F', 'M', 'S', 'U']
for row in confirmed_attack_copy2.Sex:
    if row not in sex_labels:
        confirmed_attack_copy2['Sex'].replace(to_replace=row, value='U', inplace=True)
list(confirmed_attack_copy2.Sex.unique())
# Out:
# ['U', 'F', 'M', 'S']

# %%
# Change all unknonwn names to "U"--meaning there is nothing known about the number of inviduals involved
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'Unknown', 'Name'] = 'U'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'unknown', 'Name'] = 'U'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == "Lifesavers' surf patrol boat", 'Name'] = 'U'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bBoat\b', case = 'false'), 'Name'] = 'U'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\byacht\b', case = 'false'), 'Name'] = 'U'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bcruiser\b', case = 'false'), 'Name'] = 'U'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bcutter\b', case = 'false'), 'Name'] = 'U'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\browboat\b', case = 'false'), 'Name'] = 'U'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bdinghy\b', case = 'false'), 'Name'] = 'U'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bsteamship\b', case = 'false'), 'Name'] = 'U'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\bboat\b', case = 'false'), 'Name'] = 'U'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'].str.contains(r'\blaunch\b', case = 'false'), 'Name'] = 'U'
list(confirmed_attack_copy2.Name.unique())
# Out:
# ['U',
#  'I',
#  'Nana',
#  'M',
#  '__ Jimenez',
#  'MK',
#  'Julien',
#  'Baboo',
#  'Mareen',
#  'a lifeguard',
#  'Yuma',
#  'J. Orr',
#  'S.R.B.',
#  'a marine',
#  'M.M.',
#  'child',
#  'R.J.',
#  'Sunarko',
#  'OneDLL',
#  'Rianto',
#  '"Lorrin"',
#  'teen',
#  'M.C.',
#  'Canadian teen',
#  'A visitor from Spain',
#  'occupant of a Cessna 206',
#  'Wild Oats XI',
#  'a Danish tourist',
#  'S.A.',
#  'J.L.',
#  'Unidentified',
#  'E.H.',
#  'a refugee',
#  'Emile',
#  'N.W.',
#  'Sochidjin',
#  'skiboat',
#  'A.B.',
#  'C.K.',
#  'P.L.',
#  'E.W.',
#  'J.D.',
#  'A.J.',
#  'S.D.',
#  'A.H.',
#  'an elementary school teacher',
#  'a surfer from Port Orange',
#  'A.C.C.',
#  'M.A.',
#  'G.C.',
#  'A.D',
#  'M…',
#  'G.D.',
#  'L.B.',
#  'N. F.',
#  'K.O.',
#  'College student',
#  'Marris',
#  'Hutchins',
#  'E.S.',
#  'Anonymous',
#  'C. Stokes',
#  'L.G',
#  'L.F.',
#  'a senior aquarist',
#  'Crawford',
#  'American child',
#  'Greenwood',
#  'a teenager',
# ...

# %%
num_vic_labels = ['I','M','U']
# Change the remaining names to "I" for individual, then rename "Name" column 
for row in confirmed_attack_copy2.Name:
    if row not in num_vic_labels:
        confirmed_attack_copy2['Name'].replace(to_replace=row, value='I', inplace=True)

# %%
list(confirmed_attack_copy2.Name.unique())
confirmed_attack_copy2.columns
# Out:
# Index(['Case Number', 'Name', 'Sex', 'Name2'], dtype='object')

# %%
#Rename "Name" column to be the number of victims
confirmed_attack_copy2.rename(columns = {'Name': 'People Involved'}, inplace = True)
confirmed_attack_copy2.rename(columns = {'Name2': 'Original Name'}, inplace = True)
confirmed_attack_copy2.columns
list(confirmed_attack_copy2["People Involved"].unique())
# Out:
# ['U', 'I', 'M']

# %%
#Fixing row 
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == '5.75 m wooden boat, occupant: Yoshaiaki Ueda', 'People Involved'] = 'I'

confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == '5.75 m wooden boat, occupant: Yoshaiaki Ueda', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == "25' rigid-hulled inflatable boat, HI-2", 'People Involved'] = 'U'

confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == "25' rigid-hulled inflatable boat, HI-2", 'Sex'] = 'U'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == "boat: 48' charter boat GonFishin V", 'People Involved'] = 'U'

confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == "boat: 48' charter boat GonFishin V", 'Sex'] = 'U'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == '5.4 m boat', 'People Involved'] = 'U'

confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == '5.4 m boat', 'Sex'] = 'U'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == '3 m inflatable boat tied to buoy (no occupants)', 'People Involved'] = 'U'

confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == '3 m inflatable boat tied to buoy (no occupants)', 'Sex'] = 'U'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == '2 USAF 4-engine planes (an HC-54 & a HC-97) each with 12 onboard collided in mid-air at low altitude and plunged into the Atlantic Ocean', 'People Involved'] = 'U'

confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == '2 USAF 4-engine planes (an HC-54 & a HC-97) each with 12 onboard collided in mid-air at low altitude and plunged into the Atlantic Ocean', 'Sex'] = 'U'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'Because of a mistaken belief that there were no survivors and several other successive errors, of the 100 to 150 men who survived the sinking, only 11 were rescued. Four of the Sullivan brothers died in the initial blast.', 'People Involved'] = 'U'

confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'Because of a mistaken belief that there were no survivors and several other successive errors, of the 100 to 150 men who survived the sinking, only 11 were rescued. Four of the Sullivan brothers died in the initial blast.', 'Sex'] = 'U'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'Sammy Levine & his pet parrot', 'People Involved'] = 'I'

confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == 'Sammy Levine & his pet parrot', 'Sex'] = 'M'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == '5 m skiboat', 'People Involved'] = 'U'

confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] == '5 m skiboat', 'Sex'] = 'U'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] ==  "16' motor launch owned by A. & E. Norton",'People Involved'] = 'U'

confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] ==  "16' motor launch owned by A. & E. Norton", 'Sex'] = 'U'


confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] ==  '8 US airmen in the water, 1 was bitten by a shark','People Involved'] = 'M'

confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] ==  '8 US airmen in the water, 1 was bitten by a shark', 'Sex'] = 'M'

confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] ==  '2 incidents north of Vero Beach','People Involved'] = 'I'
confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] ==  '2 incidents north of Vero Beach', 'Sex'] = 'U'

confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] ==  '4 people killed in the past week, others injured','People Involved'] = 'Unknown'

confirmed_attack_copy2.loc[confirmed_attack_copy2['Name'] ==  '4 people killed in the past week, others injured', 'Sex'] = 'U'

# %%
confirmed_attack_copy2
confirmed_attack_copy2.to_csv("victimology.csv", index=False)
