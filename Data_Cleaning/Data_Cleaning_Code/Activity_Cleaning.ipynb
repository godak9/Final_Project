# %%
# For output clarity 
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np 
import re

# %%
#Importing clearn sharks data--rows confirmed attack 
# From kaggle https://www.kaggle.com/datasets/thedevastator/shark-attacks-the-risks-of-coastal-water-activit
# FromShark Research Institute's website https://www.sharkattackfile.net/incidentlog.htm
file_path = "shark_attack_confirmed.csv"
confirmed_attack_df = pd.read_csv(file_path)
confirmed_attack_df.columns
# Out:
# Index(['index', 'Case Number', 'Date', 'Year', 'Type', 'Country', 'Area',
#        'Location', 'Activity', 'Name', 'Unnamed: 9', 'Age', 'Injury',
#        'Fatal (Y/N)', 'Time', 'Species'],
#       dtype='object')

# %%
columns = ["Case Number", "Activity"]
activity_df = confirmed_attack_df.loc[:, columns]
activity_df['Activity'].fillna('Unknown', inplace = True)

# %%
activity_df.loc[activity_df['Activity'].str.contains(r'\btank\b', case = 'false'), 'Activity'] = 'Tank_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bcaptive\b', case = 'false'), 'Activity'] = 'Tank_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bKayaking\b', case = 'false'), 'Activity'] = 'Paddle_Boat_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bkayak\b', case = 'false'), 'Activity'] = 'Paddle_Boat_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bcanoe\b', case = 'false'), 'Activity'] = 'Paddle_Boat_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bCanoe\b', case = 'false'), 'Activity'] = 'Paddle_Boat_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bRowing\b', case = 'false'), 'Activity'] = 'Paddle_Boat_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bcanoe\b', case = 'false'), 'Activity'] = 'Paddle_Boat_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bKayak\b', case = 'false'), 'Activity'] = 'Paddle_Boat_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bKakaying\b', case = 'false'), 'Activity'] = 'Paddle_Boat_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bCanoeing\b', case = 'false'), 'Activity'] = 'Paddle_Boat_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bPaddleboarding\b', case = 'false'), 'Activity'] = 'Board_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bboarding\b', case = 'false'), 'Activity'] = 'Board_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bBoarding\b', case = 'false'), 'Activity'] = 'Board_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bPaddling\b', case = 'false'), 'Activity'] = 'Board_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bcanoeing\b', case = 'false'), 'Activity'] = 'Board_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bBoard\b', case = 'false'), 'Activity'] = 'Board_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bBodyboarding\b', case = 'false'), 'Activity'] = 'Board_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bSkimboarding\b', case = 'false'), 'Activity'] = 'Board_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bKiteboarding\b', case = 'false'), 'Activity'] = 'Board_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bWakeboarding\b', case = 'false'), 'Activity'] = 'Board_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bPaddleskiing\b', case = 'false'), 'Activity'] = 'Board_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bPaddle\b', case = 'false'), 'Activity'] = 'Board_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bboard\b', case = 'false'), 'Activity'] = 'Board_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bSurfing\b', case = 'false'), 'Activity'] = 'Board_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bKite\b', case = 'false'), 'Activity'] = 'Board_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bboogie\b', case = 'false'), 'Activity'] = 'Board_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bsurfboard\b', case = 'false'), 'Activity'] = 'Board_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bSailboarding\b', case = 'false'), 'Activity'] = 'Board_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bpaddling\b', case = 'false'), 'Activity'] = 'Board_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bKitesurfing\b', case = 'false'), 'Activity'] = 'Board_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bWindsurfing\b', case = 'false'), 'Activity'] = 'Board_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bsurfing\b', case = 'false'), 'Activity'] = 'Board_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bsurfboard\b', case = 'false'), 'Activity'] = 'Board_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bSurfboard\b', case = 'false'), 'Activity'] = 'Board_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bSurfng\b', case = 'false'), 'Activity'] = 'Board_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bskiing\b', case = 'false'), 'Activity'] = 'Ski_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bski\b', case = 'false'), 'Activity'] = 'Ski_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bFilming\b', case = 'false'), 'Activity'] = 'Filming_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bBody-surfing\b', case = 'false'), 'Activity'] = 'Swimming_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bBody\b', case = 'false'), 'Activity'] = 'Swimming_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bAbalone\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\babalone\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bopihi\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bLobstering\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bbeche-de-mer\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bLobster\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bshrimp\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bScallop\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bcrayfish\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bShrimping\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\burchins\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bshell\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bprawn\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bshellfish\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bCrayfishing\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bperlemoen\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bsponges\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bPhotographing\b', case = 'false'), 'Activity'] = 'Filming_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bphotographing\b', case = 'false'), 'Activity'] = 'Filming_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bfilming\b', case = 'false'), 'Activity'] = 'Filming_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bmodeling\b', case = 'false'), 'Activity'] = 'Filming_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bWading\b', case = 'false'), 'Activity'] = 'Wading_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bwading\b', case = 'false'), 'Activity'] = 'Wading_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bWashing\b', case = 'false'), 'Activity'] = 'Wading_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bStanding\b', case = 'false'), 'Activity'] = 'Wading_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bWalking\b', case = 'false'), 'Activity'] = 'Wading_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bWade\b', case = 'false'), 'Activity'] = 'Wading_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bPlaying\b', case = 'false'), 'Activity'] = 'Wading_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bstanding\b', case = 'false'), 'Activity'] = 'Wading_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bKneeling\b', case = 'false'), 'Activity'] = 'Wading_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bCrouching\b', case = 'false'), 'Activity'] = 'Wading_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bSitting\b', case = 'false'), 'Activity'] = 'Wading_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bBathing\b', case = 'false'), 'Activity'] = 'Wading_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bLying\b', case = 'false'), 'Activity'] = 'Wading_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bStamding\b', case = 'false'), 'Activity'] = 'Wading_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bbathing\b', case = 'false'), 'Activity'] = 'Wading_Activity'

activity_df.loc[activity_df['Activity'].str.contains(r'\bwaist-deep\b', case = 'false'), 'Activity'] = 'Wading_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bSittting\b', case = 'false'), 'Activity'] = 'Wading_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bRan\b', case = 'false'), 'Activity'] = 'Wading_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bSpearfishing\b', case = 'false'), 'Activity'] = 'Spearfishing_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bspearfishing\b', case = 'false'), 'Activity'] = 'Spearfishing_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\btube\b', case = 'false'), 'Activity'] = 'Inflatable_Craft_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bfloatioon\b', case = 'false'), 'Activity'] = 'Inflatable_Craft_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\binflatable\b', case = 'false'), 'Activity'] = 'Inflatable_Craft_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bShell\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bClamming\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bscallops\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bseashells\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\blobsters\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bOyster\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bshells\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bbivalves\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\btrochus\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bbichiques\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bfloatation\b', case = 'false'), 'Activity'] = 'Inflatable_Craft_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bInflatable\b', case = 'false'), 'Activity'] = 'Inflatable_Craft_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\braft\b', case = 'false'), 'Activity'] = 'Inflatable_Craft_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bbanana\b', case = 'false'), 'Activity'] = 'Inflatable_Craft_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bfloat\b', case = 'false'), 'Activity'] = 'Inflatable_Craft_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bYacht\b', case = 'false'), 'Activity'] = 'Boat_Craft_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bSailing\b', case = 'false'), 'Activity'] = 'Boat_Craft_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bCruising\b', case = 'false'), 'Activity'] = 'Boat_Craft_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bTowing\b', case = 'false'), 'Activity'] = 'Boat_Craft_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bDropping\b', case = 'false'), 'Activity'] = 'Boat_Craft_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bSnorkeling\b', case = 'false'), 'Activity'] = 'Snorkeling_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bsnorkeling\b', case = 'false'), 'Activity'] = 'Snorkeling_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bHookah\b', case = 'false'), 'Activity'] = 'Snorkeling_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bsnorkel\b', case = 'false'), 'Activity'] = 'Snorkeling_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bobserving\b', case = 'false'), 'Activity'] = 'Observing_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bresearch\b', case = 'false'), 'Activity'] = 'Observing_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bWatching\b', case = 'false'), 'Activity'] = 'Observing_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bwatching\b', case = 'false'), 'Activity'] = 'Observing_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bsighting\b', case = 'false'), 'Activity'] = 'Observing_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bSearching\b', case = 'false'), 'Activity'] = 'Observing_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bScuba\b', case = 'false'), 'Activity'] = 'Scuba_Diving_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bscuba\b', case = 'false'), 'Activity'] = 'Scuba_Diving_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bSCUBA\b', case = 'false'), 'Activity'] = 'Scuba_Diving_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bConch\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bdollars\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bfeeding\b', case = 'false'), 'Activity'] = 'Feeding_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bFeeding\b', case = 'false'), 'Activity'] = 'Feeding_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bChumming\b', case = 'false'), 'Activity'] = 'Feeding_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bcapsized\b', case = 'false'), 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'].str.contains(r'\bDisaster\b', case = 'false'), 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'].str.contains(r'\bdisaster\b', case = 'false'), 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'].str.contains(r'\bsank\b', case = 'false'), 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'].str.contains(r'\bcollided\b', case = 'false'), 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'].str.contains(r'\bexploded\b', case = 'false'), 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'].str.contains(r'\bWreck\b', case = 'false'), 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'].str.contains(r'\bplunged\b', case = 'false'), 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'].str.contains(r'\bDeserting\b', case = 'false'), 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'].str.contains(r'\bshipwrecked\b', case = 'false'), 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'].str.contains(r'\bsinking\b', case = 'false'), 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'].str.contains(r'\bplane\b', case = 'false'), 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'].str.contains(r'\bSinking\b', case = 'false'), 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'].str.contains(r'\bfreighter\b', case = 'false'), 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'].str.contains(r'\baircraft\b', case = 'false'), 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'].str.contains(r'\bfoundered\b', case = 'false'), 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'].str.contains(r'\bExplosion\b', case = 'false'), 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'].str.contains(r'\bShipwreck\b', case = 'false'), 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'].str.contains(r'\bshipwreck\b', case = 'false'), 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'].str.contains(r'\bwreck\b', case = 'false'), 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'].str.contains(r'\bOverturned\b', case = 'false'), 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'].str.contains(r'\bCapsized\b', case = 'false'), 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'].str.contains(r'\bAbandoning\b', case = 'false'), 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'].str.contains(r'\bAdrift\b', case = 'false'), 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'].str.contains(r'\bclams\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bcrabs\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bturtles\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bmolluscs\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bturtle\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\baqarium\b', case = 'false'), 'Activity'] = 'Tank_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bAquarium\b', case = 'false'), 'Activity'] = 'Tank_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\baquarium\b', case = 'false'), 'Activity'] = 'Tank_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bshallows\b', case = 'false'), 'Activity'] = 'Wading_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bknee-deep\b', case = 'false'), 'Activity'] = 'Wading_Activity'
activity_df.loc[activity_df['Activity']== 'Leaving the water', 'Activity'] = 'Wading_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bSight-seeing\b', case = 'false'), 'Activity'] = 'Observing_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bprawns\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bspeargun\b', case = 'false'), 'Activity'] = 'Spearfishing_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bSpearing\b', case = 'false'), 'Activity'] = 'Spearfishing_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bSpear\b', case = 'false'), 'Activity'] = 'Spearfishing_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bspeared\b', case = 'false'), 'Activity'] = 'Spearfishing_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bSpeared\b', case = 'false'), 'Activity'] = 'Spearfishing_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bchild\b', case = 'false'), 'Activity'] = 'Human_Rescue_Activity'
activity_df.loc[activity_df['Activity']== 'Rescuing', 'Activity'] = 'Human_Rescue_Activity'
activity_df.loc[activity_df['Activity'] == 'Lifesaving drill', 'Activity'] = 'Human_Rescue_Activity'
activity_df.loc[activity_df['Activity'] == 'Jumped overboard to rescue a man', 'Activity'] = 'Human_Rescue_Activity'
activity_df.loc[activity_df['Activity']== 'Cage Diving', 'Activity'] = 'Cage_Diving_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bcage\b', case = 'false'), 'Activity'] = 'Cage_Diving_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bfilm\b', case = 'false'), 'Activity'] = 'Filming_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\badrift\b', case = 'false'), 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'].str.contains(r'\bAirliner\b', case = 'false'), 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity']== 'Pulling anchor', 'Activity'] = 'Boat_Craft_Activity'
activity_df.loc[activity_df['Activity']== 'On boat, preparing to dive', 'Activity'] = 'Boat_Craft_Activity'
activity_df.loc[activity_df['Activity']== 'Cleaning hull of ship', 'Activity'] = 'Boat_Craft_Activity'
activity_df.loc[activity_df['Activity']== 'Attempting to fix motor', 'Activity'] = 'Boat_Craft_Activity'
activity_df.loc[activity_df['Activity']== 'Boat stopped to repair electric pump', 'Activity'] = 'Boat_Craft_Activity'
activity_df.loc[activity_df['Activity']== '"Climbing up to ship after repairing the stern in water"', 'Activity'] = 'Boat_Craft_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bSUP\b', case = 'false'), 'Activity'] = 'Board_Activity'
activity_df.loc[activity_df['Activity']== "Accidentally stood on hooked shark's tail before attempting to gut it", 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Attempting to lasso a shark', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Fishing for sharks', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Fishing for blue sharks', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Finning the shark', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Wrangling a shark', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Shark fishing on the Ricardo Astorga', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Shark fishing on the Don Agustín-VI.', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Shark Fishing', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Finning the shark that bit him', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bSpearfishingat\b', case = 'false'), 'Activity'] = 'Spearfishing_Activity'
activity_df.loc[activity_df['Activity']== "Attempting to lasso shark's tail", 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Inspecting teeth of supposedly dead (hooked & shot) shark', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Gaffing netted shark', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Fishing for white shark', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Attempting to drag hooked shark ashore by its tail', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Pulling shark from the water', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Killing a shark', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Helping men land a shark', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Catching sharks under government contract', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'On a "shark hunt"', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Attempting to kill a shark with explosives', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity'] == 'When a deckhand jumped overboard, McIver dived after him with a rescue line.', 'Activity'] = 'Human_Rescue_Activity'
activity_df.loc[activity_df['Activity']== 'Climbing back on ship', 'Activity'] = 'Boat_Craft_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bBoating\b', case = 'false'), 'Activity'] = 'Boat_Craft_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bPearl\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bCrabbing\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bLifesaving\b', case = 'false'), 'Activity'] = 'Human_Rescue_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bgirl\b', case = 'false'), 'Activity'] = 'Human_Rescue_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\babandoned\b', case = 'false'), 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'].str.contains(r'\btorpedoed\b', case = 'false'), 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'].str.contains(r'\bsunk\b', case = 'false'), 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity']== '90 European civilians, many women & children, were placed on the deck of a Japanese submarine that submerged when it was well offshore', 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity']== 'Treading water after survivng crash of the US Navy airship K-74 that was hit by the German submarine U-134', 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity']== 'Torpedoed & burning British light cruiser with a crew of 450 men', 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity']== 'Bringing hooked, harpooned shark onboard boat', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bphotography\b', case = 'false'), 'Activity'] = 'Filming_Activity'
activity_df.loc[activity_df['Activity']== 'Known as The Battle of the Bismarck Sea : 8 Japanese destroyers guarding a convoy of 8 transports were attacked by 129 Allied fighters, 207 bombers & 3 squadrons of the Royal Australian Air Force.', 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity']== 'Anti-Aircraft cruiser USS Atlanta (CL,-05) travelling in convoy after the Battle of Midway, encountered a Japanese flotilla (Battle of Guadalcanal) &, heavily damaged by gunfire, she was lost off Lunga Point. Victim was swimming when bitten.', 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity']== 'Attempting to kill a shark with explosives', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Collecting fish in military trap when bitten by captured shark that had been shot by soldiers with Garten', 'Activity'] = 'Boat_Craft_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bHardhat\b', case = 'false'), 'Activity'] = 'Scuba_Diving_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bTrochus\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bSponge\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bSculling\b', case = 'false'), 'Activity'] = 'Board_Activity'

# %%
#activity_df.loc[activity_df['Activity'].str.contains(r'\btank\b', case = 'false'), 'Activity'] = 'Tank_Activity'
#activity_df.loc[activity_df['Activity'].str.contains(r'\bKayaking\b', case = 'false'), 'Activity'] = 'Paddle_Boat_Activity'
#activity_df.loc[activity_df['Activity'].str.contains(r'\bskiing\b', case = 'false'), 'Activity'] = 'Ski_Activity'
activity_df.loc[activity_df['Activity']== 'Testing movie camera in full diving dress', 'Activity'] = 'Filming_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bBodysurfing\b', case = 'false'), 'Activity'] = 'Swimming_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\btrepang\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\blobster\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'] == 'Riding horseback across the creek', 'Activity'] = 'Wading_Activity'
#activity_df.loc[activity_df['Activity'].str.contains(r'\bSpearfishing\b', case = 'false'), 'Activity'] = 'Spearfishing_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bmattress\b', case = 'false'), 'Activity'] = 'Inflatable_Craft_Activity'
activity_df.loc[activity_df['Activity']== 'Boat', 'Activity'] = 'Boat_Craft_Activity'
#activity_df.loc[activity_df['Activity'].str.contains(r'\bSnorkeling\b', case = 'false'), 'Activity'] = 'Snorkeling_Activity'
activity_df.loc[activity_df['Activity']== 'Attempting to attract dolphins', 'Activity'] = 'Observing_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bHelmet\b', case = 'false'), 'Activity'] = 'Scuba_Diving_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bhat\b', case = 'false'), 'Activity'] = 'Scuba_Diving_Activity'
#activity_df.loc[activity_df['Activity'].str.contains(r'\bChumming\b', case = 'false'), 'Activity'] = 'Feeding_Activity'
activity_df.loc[activity_df['Activity'] == 'Fishing boat swamped in a storm', 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity']== 'Attempting to rescue drowning man', 'Activity'] = 'Human_Rescue_Activity'
#activity_df.loc[activity_df['Activity'].str.contains(r'\bcage\b', case = 'false'), 'Activity'] = 'Cage_Diving_Activity'
activity_df.loc[activity_df['Activity']== 'Shark fishing', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Longline fishing for sharks', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Killing sharks', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Helping friend land hooked shark', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Helping friend land hooked shark', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Swimming out to rescue swimmers in difficulty', 'Activity'] = 'Human_Rescue_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bDress\b', case = 'false'), 'Activity'] = 'Scuba_Diving_Activity'
activity_df.loc[activity_df['Activity'] == 'Riding a horse', 'Activity'] = 'Wading_Activity'

# %%
activity_df.loc[activity_df['Activity']== 'Grabbing shark for a selfie', 'Activity'] = 'Shark_Handling_Activity'
activity_df.loc[activity_df['Activity']== 'Touching a shark', 'Activity'] = 'Shark_Handling_Activity'
activity_df.loc[activity_df['Activity']== 'Tagging sharks', 'Activity'] = 'Shark_Handling_Activity'
activity_df.loc[activity_df['Activity']== 'Teasing a shark', 'Activity'] = 'Shark_Handling_Activity'
activity_df.loc[activity_df['Activity']== 'Petting a shark', 'Activity'] = 'Shark_Handling_Activity'
activity_df.loc[activity_df['Activity']== 'Measuring sharks', 'Activity'] = 'Shark_Handling_Activity'
activity_df.loc[activity_df['Activity']== 'Reviving a sedated shark', 'Activity'] = 'Shark_Handling_Activity'
activity_df.loc[activity_df['Activity']== 'Shark tagging', 'Activity'] = 'Shark_Handling_Activity'

activity_df.loc[activity_df['Activity']== 'Picking up shark by the tail', 'Activity'] = 'Shark_Handling_Activity'
activity_df.loc[activity_df['Activity']== 'Attempting to anesthetize shark', 'Activity'] = 'Shark_Handling_Activity'
activity_df.loc[activity_df['Activity']== 'Holding shark on leader & dangling it above the water', 'Activity'] = 'Shark_Handling_Activity'
activity_df.loc[activity_df['Activity']== 'Slapped shark on tail as it swam by', 'Activity'] = 'Shark_Handling_Activity'
activity_df.loc[activity_df['Activity']== 'Placed hand in disemboweled shark’s jaws', 'Activity'] = 'Shark_Handling_Activity'
activity_df.loc[activity_df['Activity']== 'Grabbed shark & threw it on deck', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Attempting to ride a shark', 'Activity'] = 'Shark_Handling_Activity'
activity_df.loc[activity_df['Activity']== 'Touching the mouth of a supposedly dead shark', 'Activity'] = 'Shark_Handling_Activity'
activity_df.loc[activity_df['Activity']== 'Put foot inside a landed & supposedly dead shark', 'Activity'] = 'Shark_Handling_Activity'
activity_df.loc[activity_df['Activity']== 'Feeling the shark’s teeth', 'Activity'] = 'Shark_Handling_Activity'
activity_df.loc[activity_df['Activity']== 'Helping angler land a shark', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Hauling in net with shark in it', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Landing hooked shark in boat', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Fishing for white sharks', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Fishing for the shark that killed George Lundberg', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Examining netted shark, that had been shot', 'Activity'] = 'Shark_Hunting_Activity'

# %%
activity_df.loc[activity_df['Activity']== 'Attempting to rescue a shark', 'Activity'] = 'Shark_Rescue_Activity'
activity_df.loc[activity_df['Activity']== 'Attempting to free the shark', 'Activity'] = 'Shark_Rescue_Activity'
activity_df.loc[activity_df['Activity']== 'Dragging stranded shark into deeper water', 'Activity'] = 'Shark_Rescue_Activity'
activity_df.loc[activity_df['Activity']== 'Attempting to rescue an injured & beached shark', 'Activity'] = 'Shark_Rescue_Activity'
activity_df.loc[activity_df['Activity']== 'Attempting to chase shark out to sea', 'Activity'] = 'Shark_Rescue_Activity'
activity_df.loc[activity_df['Activity']== 'Removing hook from shark', 'Activity'] = 'Shark_Rescue_Activity'
activity_df.loc[activity_df['Activity']== 'Removing shark from net', 'Activity'] = 'Shark_Rescue_Activity'
activity_df.loc[activity_df['Activity']== 'Attempting to drive shark away from sailing regatta', 'Activity'] = 'Shark_Rescue_Activity'
activity_df.loc[activity_df['Activity']== 'Moving a shark in a net', 'Activity'] = 'Shark_Rescue_Activity'
activity_df.loc[activity_df['Activity']== 'Attempting to drive shark away from the beach', 'Activity'] = 'Shark_Rescue_Activity'
activity_df.loc[activity_df['Activity']== 'Hoisting shark aboard fishing boat', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Attempted to return injured shark to the sea', 'Activity'] = 'Shark_Rescue_Activity'
activity_df.loc[activity_df['Activity']== 'Bitten while cutting shark from net', 'Activity'] = 'Shark_Rescue_Activity'
activity_df.loc[activity_df['Activity']== 'Moving shark from tuna vessel when boat rolled, placing both man & shark in chest-deep water', 'Activity'] = 'Shark_Rescue_Activity'
activity_df.loc[activity_df['Activity']== 'Removing shark from a trap', 'Activity'] = 'Shark_Rescue_Activity'
activity_df.loc[activity_df['Activity']== 'Shooting sharks', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Hunting sharks', 'Activity'] = 'Shark_Hunting_Activity'

# %%
activity_df.loc[activity_df['Activity'].str.contains(r'\bSkindiving\b', case = 'false'), 'Activity'] = 'Snorkeling_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bSkin\b', case = 'false'), 'Activity'] = 'Snorkeling_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bskin\b', case = 'false'), 'Activity'] = 'Snorkeling_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bOystering\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bpearl\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bshelling\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bFell\b', case = 'false'), 'Activity'] = 'Falling_Into_Water'
activity_df.loc[activity_df['Activity'].str.contains(r'\bfalling\b', case = 'false'), 'Activity'] = 'Falling_Into_Water'
activity_df.loc[activity_df['Activity'].str.contains(r'\boverboard\b', case = 'false'), 'Activity'] = 'Falling_Into_Water'
activity_df.loc[activity_df['Activity'].str.contains(r'\bswept\b', case = 'false'), 'Activity'] = 'Falling_Into_Water'
activity_df.loc[activity_df['Activity'].str.contains(r'\bBending\b', case = 'false'), 'Activity'] = 'Falling_Into_Water'
activity_df.loc[activity_df['Activity'].str.contains(r'\bParachuted\b', case = 'false'), 'Activity'] = 'Falling_Into_Water'
activity_df.loc[activity_df['Activity'].str.contains(r'\btorpedoes\b', case = 'false'), 'Activity'] = 'Falling_Into_Water'
activity_df.loc[activity_df['Activity'].str.contains(r'\bSwept\b', case = 'false'), 'Activity'] = 'Falling_Into_Water'
activity_df.loc[activity_df['Activity']== 'His balloon crashed in the harbor', 'Activity'] = 'Falling_Into_Water'
activity_df.loc[activity_df['Activity']== 'Diving, attempting to retrieve body of drowning victim wedged between rocks', 'Activity'] = 'Human_Rescue_Activity'
activity_df.loc[activity_df['Activity'] == 'Among 31 survivors of crew from the sampan Fukulya Maru (which reached Thursday Island in rowing boat) was a man whose arm had been bitten off by shark. The sampan wrecked west of McArthur island', 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'] == 'Hurricane & Tidal Wave', 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'] == 'seaplane Columbus ditched in the sea', 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'] == 'Boat swamped', 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'] == 'Shipwrecked pearling schooner', 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'] == 'Loss of the schooner Nomad', 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'] == 'A barque wrecked', 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'] == 'Loss of the schooner Nomad', 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'] == 'Escaping from blackbirding vessel', 'Activity'] = 'Sea_Disaster'

activity_df.loc[activity_df['Activity'] == 'Burning of the S.S. Missouri', 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'].str.contains(r'\bShipwrecked\b', case = 'false'), 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'] == 'boat from the Austrian ship Elizabeth', 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'] == 'Boat of a Hawaiian brig was stove in by whale', 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity']== 'Attempting to rescue shipmate', 'Activity'] = 'Human_Rescue_Activity'
activity_df.loc[activity_df['Activity']== 'Attempting to rescue woman seized by shark', 'Activity'] = 'Human_Rescue_Activity'
activity_df.loc[activity_df['Activity'] == 'The passenger ship Kapuna was run down the ore carrier Ada Melmore', 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'] == 'Pacific Seafarer of US Navy', 'Activity'] = 'Sea_Disaster'

# %%
activity_df.loc[activity_df['Activity'].str.contains(r'\bFloating\b', case = 'false'), 'Activity'] = 'Swimming_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bJumping\b', case = 'false'), 'Activity'] = 'Swimming_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bjumping\b', case = 'false'), 'Activity'] = 'Swimming_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bTreading\b', case = 'false'), 'Activity'] = 'Swimming_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\btreading\b', case = 'false'), 'Activity'] = 'Swimming_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bSplashing\b', case = 'false'), 'Activity'] = 'Swimming_Activity'
activity_df.loc[activity_df['Activity'] == 'In water with diving seabirds', 'Activity'] = 'Swimming_Activity'
activity_df.loc[activity_df['Activity'] == 'Attempting to retreive a dinghy', 'Activity'] = 'Swimming_Activity'
activity_df.loc[activity_df['Activity'] == 'Attacked shark with fists', 'Activity'] = 'Swimming_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bJumped\b', case = 'false'), 'Activity'] = 'Swimming_Activity'
activity_df.loc[activity_df['Activity']== 'Touching sharks', 'Activity'] = 'Shark_Handling_Activity'
activity_df.loc[activity_df['Activity']== "Days before the surrender of Singapore, the 3 men escaped to Sumatra where they acquired a 17' dinghy. After 125 days at sea they drifted back to Sumatra", 'Activity'] = 'Boat_Craft_Activity'
activity_df.loc[activity_df['Activity']== 'Ocean racing', 'Activity'] = 'Boat_Craft_Activity'
activity_df.loc[activity_df['Activity']== 'Defecating in water beneath the docks', 'Activity'] = 'Wading_Activity'
activity_df.loc[activity_df['Activity']== 'Sleeping in anchored boat', 'Activity'] = 'Boat_Craft_Activity'
activity_df.loc[activity_df['Activity']== 'Pleasure boating', 'Activity'] = 'Boat_Craft_Activity'
activity_df.loc[activity_df['Activity']== "Diving to untangle a crab trap line from boat's propeller", 'Activity'] = 'Boat_Craft_Activity'
activity_df.loc[activity_df['Activity']== 'Hauling dead shark aboard, when another shark leapt out of the water & bit him', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'In rubber dinghy with Captain Eddie Rickenbacker for 21 days.', 'Activity'] = 'Boat_Craft_Activity'
activity_df.loc[activity_df['Activity']== '"Boat accident"', 'Activity'] = 'Boat_Craft_Activity'
activity_df.loc[activity_df['Activity']== "Holding shark's tail", 'Activity'] = 'Shark_Handling_Activity'
activity_df.loc[activity_df['Activity']== 'Put foot inside mouth of supposedly dead shark', 'Activity'] = 'Shark_Handling_Activity'
activity_df.loc[activity_df['Activity']== 'Removing shark from a net', 'Activity'] = 'Shark_Rescue_Activity'
activity_df.loc[activity_df['Activity']== 'Harpooned shark', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Fishing for basking sharks', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Stuffing a shark into an automobile', 'Activity'] = 'Shark_Handling_Activity'
activity_df.loc[activity_df['Activity'] == 'British ship Macedon was thrown on her beam ends by a sudden squall', 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity']== 'Restraining a beached shark', 'Activity'] = 'Shark_Handling_Activity'
activity_df.loc[activity_df['Activity']== 'Harassing a shark', 'Activity'] = 'Shark_Handling_Activity'
activity_df.loc[activity_df['Activity']== 'Dragging a shark', 'Activity'] = 'Shark_Handling_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bThrown\b', case = 'false'), 'Activity'] = 'Falling_Into_Water'
activity_df.loc[activity_df['Activity'].str.contains(r'\bKnocked\b', case = 'false'), 'Activity'] = 'Falling_Into_Water'
activity_df.loc[activity_df['Activity'].str.contains(r'\bpearls\b', case = 'false'), 'Activity'] = 'Shellfish_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'yachting accident', 'Activity'] = 'Boat_Craft_Activity'
activity_df.loc[activity_df['Activity']== 'In boat being towed by ship, Karnak', 'Activity'] = 'Boat_Craft_Activity'
activity_df.loc[activity_df['Activity']== 'Launching a boat', 'Activity'] = 'Boat_Craft_Activity'
activity_df.loc[activity_df['Activity']== 'Reaching for life preserver', 'Activity'] = 'Boat_Craft_Activity'
activity_df.loc[activity_df['Activity']== 'Painting a ship', 'Activity'] = 'Boat_Craft_Activity'
activity_df.loc[activity_df['Activity']== 'Spent 8 days in dinghy', 'Activity'] = 'Boat_Craft_Activity'
activity_df.loc[activity_df['Activity']== 'Ship lay at anchor & man was working on its rudder', 'Activity'] = 'Boat_Craft_Activity'
activity_df.loc[activity_df['Activity']== 'Traveling by boat', 'Activity'] = 'Boat_Craft_Activity'
activity_df.loc[activity_df['Activity']== 'Attempting to rescue crew after whale upset their boat', 'Activity'] = 'Human_Rescue_Activity'
activity_df.loc[activity_df['Activity'] == 'Washed off catamaran in the surf', 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'] == 'Aircraft ditched in the sea, swimming ashore', 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'] == 'ship William Penn grounded & broke apart', 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'] == 'Gloucester fishing schooner run down', 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'] == 'Steamer Una wrecked with 75 laborers onboard. Survivors took to rafts & lifeboats.', 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity'] == 'Swimming, after boat swamped', 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity']== 'Attempting to drive shark from area', 'Activity'] = 'Shark_Rescue_Activity'
activity_df.loc[activity_df['Activity']== 'Fishing, tossing netted shark onboard', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Carrying a supposedly dead shark by its mouth', 'Activity'] = 'Shark_Handling_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bWooden\b', case = 'false'), 'Activity'] = 'Paddle_Boat_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bcanoes\b', case = 'false'), 'Activity'] = 'Paddle_Boat_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\browing\b', case = 'false'), 'Activity'] = 'Paddle_Boat_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\boar\b', case = 'false'), 'Activity'] = 'Paddle_Boat_Activity'
activity_df.loc[activity_df['Activity']== 'Commercial Salvage Diving', 'Activity'] = 'Scuba_Diving_Activity'
activity_df.loc[activity_df['Activity']== 'Cleaning the side of a ship', 'Activity'] = 'Boat_Craft_Activity'
activity_df.loc[activity_df['Activity']== 'Trailing hand in the water', 'Activity'] = 'Boat_Craft_Activity'
activity_df.loc[activity_df['Activity']== 'Watercraft', 'Activity'] = 'Boat_Craft_Activity'
activity_df.loc[activity_df['Activity']== 'Launching rowboat through the surf', 'Activity'] = 'Boat_Craft_Activity'
activity_df.loc[activity_df['Activity']== 'Gaffing & attempting to bring onboard a harpooned shark', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Closed circuit diving (submerged). Diving to recover jettisoned packets of opium for police' , 'Activity'] = 'Scuba_Diving_Activity'
activity_df.loc[activity_df['Activity']== 'Free diving, working on U/W scenes for motion picture', 'Activity'] = 'Filming_Activity'
activity_df.loc[activity_df['Activity']== 'Fishing, hooked shark towed boat out to sea, storm swamped boat', 'Activity'] = 'Shark_Hunting_Activity'
activity_df.loc[activity_df['Activity']== 'Diving / Kissing the shark', 'Activity'] = 'Shark_Handling_Activity'

# %%
activity_df.loc[activity_df['Activity'].str.contains(r'\bDiving\b', case = 'false'), 'Activity'] = 'Free_Diving_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bdiving\b', case = 'false'), 'Activity'] = 'Free_Diving_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bDived\b', case = 'false'), 'Activity'] = 'Free_Diving_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bFreediving\b', case = 'false'), 'Activity'] = 'Free_Diving_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bdived\b', case = 'false'), 'Activity'] = 'Free_Diving_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bdive\b', case = 'false'), 'Activity'] = 'Free_Diving_Activity'
activity_df.loc[activity_df['Activity'] == 'Attempting to set underwater endurance record', 'Activity'] = 'Free_Diving_Activity'
activity_df.loc[activity_df['Activity']== 'Fishing, sitting in stern of small boat, feet dangling in the water', 'Activity'] = 'Boat_Craft_Activity'
activity_df.loc[activity_df['Activity'] == 'American minesweeper USS YMS-350 lost in a typhoon - swimming to shore', 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity']== 'Dismantling cable buoys of the cable ship All America', 'Activity'] = 'Boat_Craft_Activity'

# %%
activity_df.loc[activity_df['Activity'].str.contains(r'\bSwimming\b', case = 'false'), 'Activity'] = 'Swimming_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bThrashing\b', case = 'false'), 'Activity'] = 'Swimming_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bswimming\b', case = 'false'), 'Activity'] = 'Swimming_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bEscaping\b', case = 'false'), 'Activity'] = 'Swimming_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bTrailing\b', case = 'false'), 'Activity'] = 'Swimming_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bCrossing\b', case = 'false'), 'Activity'] = 'Swimming_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bFleeing\b', case = 'false'), 'Activity'] = 'Swimming_Activity'

activity_df.loc[activity_df['Activity'] == 'In deep water about 100 yards from his ship', 'Activity'] = 'Swimming_Activity'
activity_df.loc[activity_df['Activity'] == 'Taking wife to beach & about 1 m from the shore', 'Activity'] = 'Swimming_Activity'
activity_df.loc[activity_df['Activity'] == 'Coming ashore on a hawser', 'Activity'] = 'Swimming_Activity'
activity_df.loc[activity_df['Activity'] == 'Trying to catch a wounded bird', 'Activity'] = 'Swimming_Activity'

# %%
activity_df.loc[activity_df['Activity'].str.contains(r'\bFishing\b', case = 'false'), 'Activity'] = 'Fishing_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bfishing\b', case = 'false'), 'Activity'] = 'Fishing_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bnet\b', case = 'false'), 'Activity'] = 'Fishing_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bCleaning\b', case = 'false'), 'Activity'] = 'Fishing_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bBatin\b', case = 'false'), 'Activity'] = 'Fishing_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bCatching\b', case = 'false'), 'Activity'] = 'Fishing_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bFishingat\b', case = 'false'), 'Activity'] = 'Fishing_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bjack-mackerel\b', case = 'false'), 'Activity'] = 'Fishing_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\btrap\b', case = 'false'), 'Activity'] = 'Fishing_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bshad\b', case = 'false'), 'Activity'] = 'Fishing_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bseine\b', case = 'false'), 'Activity'] = 'Fishing_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bflounder\b', case = 'false'), 'Activity'] = 'Fishing_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bfish\b', case = 'false'), 'Activity'] = 'Fishing_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bSeine\b', case = 'false'), 'Activity'] = 'Fishing_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bsalmon\b', case = 'false'), 'Activity'] = 'Fishing_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bAngling\b', case = 'false'), 'Activity'] = 'Fishing_Activity'
activity_df.loc[activity_df['Activity']== 'Slipped off rocks and fell into the water', 'Activity'] = 'Falling_Into_Water'
activity_df.loc[activity_df['Activity']== 'Lashing logs together when he fell into the water', 'Activity'] = 'Falling_Into_Water'
activity_df.loc[activity_df['Activity']== 'Inebriated, woke from sleep and fell off deck into the water', 'Activity'] = 'Falling_Into_Water'
activity_df.loc[activity_df['Activity']== 'Working on the bridge when he fell into the river', 'Activity'] = 'Falling_Into_Water'
activity_df.loc[activity_df['Activity'] == "a corsair's boat was overturned", 'Activity'] = 'Sea_Disaster'
activity_df.loc[activity_df['Activity']== 'Dragging stranded shark ashore', 'Activity'] = 'Shark_Handling_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bUnknown\b', case = 'false'), 'Activity'] = 'Unknown_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bmale\b', case = 'false'), 'Activity'] = 'Unknown_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bhead\b', case = 'false'), 'Activity'] = 'Unknown_Activity'
activity_df.loc[activity_df['Activity'].str.contains(r'\bHilo\b', case = 'false'), 'Activity'] = 'Unknown_Activity'
activity_df.loc[activity_df['Activity'] == '.', 'Activity'] = 'Unknown_Activity'

# %%
activity_list = ['Board_Activity',
                 'Swimming_Activity',
                 'Scuba_Diving_Activity',
                 'Unknown_Activity',
                 'Falling_Into_Water',
                 'Spearfishing_Activity',
                 'Ski_Activity',
                 'Fishing_Activity',
                 'Paddle_Boat_Activity',
                 'Free_Diving_Activity',
                 'Snorkeling_Activity',
                 'Feeding_Activity',
                 'Wading_Activity',
                 'Shellfish_Hunting_Activity',
                 'Tank_Activity',
                 'Sea_Disaster',
                 'Shark_Handling_Activity',
                 'Shark_Hunting_Activity',
                 'Cage_Diving_Activity',
                 'Inflatable_Craft_Activity',
                 'Filming_Activity',
                 'Shark_Rescue_Activity',
                 'Observing_Activity',
                 'Boat_Craft_Activity',
                 'Human_Rescue_Activity']
for row in activity_df.Activity:
    if row not in activity_list:
        activity_df['Activity'].replace(to_replace=row, value='Misc_Activity', inplace= True)
list(activity_df.Activity.unique())
# Out:
# ['Board_Activity',
#  'Swimming_Activity',
#  'Scuba_Diving_Activity',
#  'Unknown_Activity',
#  'Falling_Into_Water',
#  'Spearfishing_Activity',
#  'Ski_Activity',
#  'Fishing_Activity',
#  'Paddle_Boat_Activity',
#  'Free_Diving_Activity',
#  'Snorkeling_Activity',
#  'Feeding_Activity',
#  'Wading_Activity',
#  'Shellfish_Hunting_Activity',
#  'Tank_Activity',
#  'Sea_Disaster',
#  'Shark_Handling_Activity',
#  'Shark_Hunting_Activity',
#  'Cage_Diving_Activity',
#  'Inflatable_Craft_Activity',
#  'Filming_Activity',
#  'Shark_Rescue_Activity',
#  'Observing_Activity',
#  'Boat_Craft_Activity',
#  'Human_Rescue_Activity',
#  'Misc_Activity']

# %%
activity_df.to_csv("activity.csv", index=False)
