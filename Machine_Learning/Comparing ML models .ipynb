# %%
from sqlalchemy import create_engine
# You must have psycopg2 installed in your choosen environment
#!pip install psycopg2-binary
import psycopg2
import pandas as pd
# Configure settings for RDS
from getpass import getpass
password = getpass('Enter database password')
mode = "read"
jdbc_url=""
config = {"user":"postgres", 
          "password": password, 
          "driver":"org.postgresql.Driver"}
# Out:
# Enter database password········

# %%
# Establish connection to database 
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/shark_bite_db"
engine = create_engine(db_string)
conn = engine.connect()

# %%
shark_bite_df = pd.read_sql_table('completedata', conn )
shark_bite_df
# Out:
#        case_number    year  month   day country              activity  \
# 0       2020.02.05  2020.0    2.0   5.0     USA        Board_Activity
# 1     2020.01.30.R  2020.0    1.0  30.0     BHS     Swimming_Activity
# 2       2020.01.17  2020.0    1.0  17.0     AUS        Board_Activity
# 3       2020.01.16  2020.0    1.0  16.0     NZL        Board_Activity
# 4       2020.01.13  2020.0    1.0  13.0     USA        Board_Activity
# ...            ...     ...    ...   ...     ...                   ...
# 5914    1923.01.13  1923.0    1.0  13.0     CUB          Sea_Disaster
# 5915    1872.11.24  1872.0   11.0  24.0     OTH      Unknown_Activity
# 5916  1967.09.07.b  1967.0    9.0   7.0     PNG  Free_Diving_Activity
# 5917    2001.11.07  2001.0   11.0   7.0     AUS          Ski_Activity
# 5918    1870.00.00     NaN    NaN   NaN     AUS  Paddle_Boat_Activity
#
#                     species        type people_involved sex fatal
# 0                     Tiger  Unprovoked               U   U     N
# 1                   Unknown    Provoked               I   F     N
# 2                   Unknown  Unprovoked               I   M     N
# 3     Broad_Nose_Seven_Gill  Unprovoked               I   F     N
# 4                   Unknown  Unprovoked               I   M     N
# ...                     ...         ...             ...  ..   ...
# 5914             Dusky_Reef     Unknown               I   M  None
# 5915                Unknown     Unknown               I   F  None
# 5916                Unknown    Provoked               I   U  None
# 5917                Unknown     Unknown               I   M  None
# 5918                Unknown     Unknown               I   M  None
#
# [5919 rows x 11 columns]

# %%
print(len(shark_bite_df))
# Out:
# 5919

# %%
shark_bite_df.dropna(how = 'any', axis = 0, inplace= True)
shark_bite_df
# Out:
#        case_number    year  month   day country           activity  \
# 0       2020.02.05  2020.0    2.0   5.0     USA     Board_Activity
# 1     2020.01.30.R  2020.0    1.0  30.0     BHS  Swimming_Activity
# 2       2020.01.17  2020.0    1.0  17.0     AUS     Board_Activity
# 3       2020.01.16  2020.0    1.0  16.0     NZL     Board_Activity
# 4       2020.01.13  2020.0    1.0  13.0     USA     Board_Activity
# ...            ...     ...    ...   ...     ...                ...
# 5705    1751.07.27  1751.0    7.0  27.0     USA  Swimming_Activity
# 5708    1742.12.17  1742.0   12.0  17.0     OTH  Swimming_Activity
# 5709  1738.04.06.R  1738.0    4.0   6.0     ITA  Swimming_Activity
# 5712    1703.03.26  1703.0    3.0  26.0     OTH  Swimming_Activity
# 5718  1580.01.10.R  1580.0    1.0  10.0     OTH     Board_Activity
#
#                     species        type people_involved sex fatal
# 0                     Tiger  Unprovoked               U   U     N
# 1                   Unknown    Provoked               I   F     N
# 2                   Unknown  Unprovoked               I   M     N
# 3     Broad_Nose_Seven_Gill  Unprovoked               I   F     N
# 4                   Unknown  Unprovoked               I   M     N
# ...                     ...         ...             ...  ..   ...
# 5705                Unknown  Unprovoked               I   M     Y
# 5708                Unknown  Unprovoked               M   S     Y
# 5709                Unknown  Unprovoked               I   M     Y
# 5712                Unknown  Unprovoked               I   M     N
# 5718                Unknown  Unprovoked               I   M     Y
#
# [5056 rows x 11 columns]
