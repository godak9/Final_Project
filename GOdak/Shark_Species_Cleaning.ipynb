# %%
# For output clarity 
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np 
import re

# %%
#Importing sharks data 
# From kaggle https://www.kaggle.com/datasets/thedevastator/shark-attacks-the-risks-of-coastal-water-activit
# FromShark Research Institute's website https://www.sharkattackfile.net/incidentlog.htm
file_path = "Shark_attack_data_raw.csv"
raw_df = pd.read_csv(file_path)
raw_df.columns
# Out:
# Index(['index', 'Case Number', 'Date', 'Year', 'Type', 'Country', 'Area',
#        'Location', 'Activity', 'Name',
#        ...
#        'Unnamed: 246', 'Unnamed: 247', 'Unnamed: 248', 'Unnamed: 249',
#        'Unnamed: 250', 'Unnamed: 251', 'Unnamed: 252', 'Unnamed: 253',
#        'Unnamed: 254', 'Unnamed: 255'],
#       dtype='object', length=257)

# %%
list(raw_df.columns)
# Out:
# ['index',
#  'Case Number',
#  'Date',
#  'Year',
#  'Type',
#  'Country',
#  'Area',
#  'Location',
#  'Activity',
#  'Name',
#  'Unnamed: 9',
#  'Age',
#  'Injury',
#  'Fatal (Y/N)',
#  'Time',
#  'Species ',
#  'Investigator or Source',
#  'pdf',
#  'href formula',
#  'href',
#  'Case Number.1',
#  'Case Number.2',
#  'original order',
#  'Unnamed: 22',
#  'Unnamed: 23',
#  'Unnamed: 24',
#  'Unnamed: 25',
#  'Unnamed: 26',
#  'Unnamed: 27',
#  'Unnamed: 28',
#  'Unnamed: 29',
#  'Unnamed: 30',
#  'Unnamed: 31',
#  'Unnamed: 32',
#  'Unnamed: 33',
#  'Unnamed: 34',
#  'Unnamed: 35',
#  'Unnamed: 36',
#  'Unnamed: 37',
#  'Unnamed: 38',
#  'Unnamed: 39',
#  'Unnamed: 40',
#  'Unnamed: 41',
#  'Unnamed: 42',
#  'Unnamed: 43',
#  'Unnamed: 44',
#  'Unnamed: 45',
#  'Unnamed: 46',
#  'Unnamed: 47',
#  'Unnamed: 48',
#  'Unnamed: 49',
#  'Unnamed: 50',
#  'Unnamed: 51',
#  'Unnamed: 52',
#  'Unnamed: 53',
#  'Unnamed: 54',
#  'Unnamed: 55',
#  'Unnamed: 56',
#  'Unnamed: 57',
# ...

# %%
# Importing without all the unnamed columns with empty values 
columns = [
    'index',
    'Case Number',
    'Date',
    'Year',
    'Type',
    'Country',
    'Area',
    'Location',
    'Activity',
    'Name',
    'Unnamed: 9',
    'Age',
    'Injury',
    'Fatal (Y/N)',
    'Time',
    'Species ',
    'Investigator or Source',
    'pdf',
    'href formula',
    'href',
    'Case Number.1',
    'Case Number.2',
    'original order'
]
selected_df = raw_df.loc[:, columns]
selected_df
# Out:
#       index   Case Number                  Date    Year        Type  \
# 0         0    2020.02.05              5-Feb-20  2020.0  Unprovoked
# 1         1  2020.01.30.R  Reported 30-Jan-2020  2020.0    Provoked
# 2         2    2020.01.17             17-Jan-20  2020.0  Unprovoked
# 3         3    2020.01.16             16-Jan-20  2020.0  Unprovoked
# 4         4    2020.01.13             13-Jan-20  2020.0  Unprovoked
# ...     ...           ...                   ...     ...         ...
# 6457   6457       ND.0005           Before 1903     0.0  Unprovoked
# 6458   6458       ND.0004           Before 1903     0.0  Unprovoked
# 6459   6459       ND.0003             1900-1905     0.0  Unprovoked
# 6460   6460       ND.0002             1883-1889     0.0  Unprovoked
# 6461   6461       ND.0001             1845-1853     0.0  Unprovoked
#
#                  Country               Area  \
# 0                    USA               Maui
# 1                BAHAMAS             Exumas
# ...

# %%
# Dropping duplicate columns 
selected_unique_df = selected_df.drop(['Case Number.1', 'Case Number.2'], axis=1)
selected_unique_df
# Out:
#       index   Case Number                  Date    Year        Type  \
# 0         0    2020.02.05              5-Feb-20  2020.0  Unprovoked
# 1         1  2020.01.30.R  Reported 30-Jan-2020  2020.0    Provoked
# 2         2    2020.01.17             17-Jan-20  2020.0  Unprovoked
# 3         3    2020.01.16             16-Jan-20  2020.0  Unprovoked
# 4         4    2020.01.13             13-Jan-20  2020.0  Unprovoked
# ...     ...           ...                   ...     ...         ...
# 6457   6457       ND.0005           Before 1903     0.0  Unprovoked
# 6458   6458       ND.0004           Before 1903     0.0  Unprovoked
# 6459   6459       ND.0003             1900-1905     0.0  Unprovoked
# 6460   6460       ND.0002             1883-1889     0.0  Unprovoked
# 6461   6461       ND.0001             1845-1853     0.0  Unprovoked
#
#                  Country               Area  \
# 0                    USA               Maui
# 1                BAHAMAS             Exumas
# ...

# %%
# Dropping Source info 
clean_species_df = selected_unique_df.drop([
    'Investigator or Source', 'pdf', 'href formula', 'href', 'original order', 'Name', 'Unnamed: 9'
], axis =1)
clean_species_df
# Out:
#       index   Case Number                  Date    Year        Type  \
# 0         0    2020.02.05              5-Feb-20  2020.0  Unprovoked
# 1         1  2020.01.30.R  Reported 30-Jan-2020  2020.0    Provoked
# 2         2    2020.01.17             17-Jan-20  2020.0  Unprovoked
# 3         3    2020.01.16             16-Jan-20  2020.0  Unprovoked
# 4         4    2020.01.13             13-Jan-20  2020.0  Unprovoked
# ...     ...           ...                   ...     ...         ...
# 6457   6457       ND.0005           Before 1903     0.0  Unprovoked
# 6458   6458       ND.0004           Before 1903     0.0  Unprovoked
# 6459   6459       ND.0003             1900-1905     0.0  Unprovoked
# 6460   6460       ND.0002             1883-1889     0.0  Unprovoked
# 6461   6461       ND.0001             1845-1853     0.0  Unprovoked
#
#                  Country               Area  \
# 0                    USA               Maui
# 1                BAHAMAS             Exumas
# ...

# %%
null_cols = clean_species_df.isnull().sum()
null_cols[null_cols > 0]
# Out:
# Case Number       2
# Date              1
# Year              3
# Type              5
# Country          51
# Area            463
# Location        545
# Activity        552
# Age            2871
# Injury           29
# Fatal (Y/N)     547
# Time           3392
# Species        2924
# dtype: int64

# %%
# Cleaning 'Species' column
# Rename column, remove space
clean_species_df.rename(columns = {'Species ': 'Species'}, inplace = True)
list(clean_species_df.Species.unique())
# Out:
# ['Tiger shark',
#  nan,
#  '"A small shark"',
#  'Broadnose seven gill shark?',
#  'Lemon shark',
#  'White shark',
#  'Shovelnose "shark" which is a ray, not a shark)',
#  '3.4 m tiger shark',
#  "10'-12' tiger shark",
#  'Juvenile blacktip shark',
#  "5' blacktip shark",
#  "4' to 5' blacktip shark",
#  'White shark, 4 m',
#  "10' tiger shark",
#  "4' to 5' shark",
#  'Oceanic whitetip shark',
#  "7' shark",
#  'White shark, 3.5 m',
#  'Juvenile shark',
#  '1+ m shark',
#  "6' to 7' shark",
#  "2' shark",
#  "14' white shark",
#  'Nurse shark',
#  "6.5' shark",
#  "10' to 12' shark",
#  "Blacktip shark, 5'",
#  'Blacktip or Spinner shark',
#  'Sandtiger shark',
#  'White shark, 3m',
#  'shark pup',
#  'White shark, juvenile',
#  'Bull shark pup',
#  "Bull shark, 4' to 5'",
#  'Bull shark, 3.5 m',
#  'Shark involvement unconfirmed but considered probable',
#  "8' shark",
#  'Grey nurse shark, 3 m female',
#  'Cookiecutter shark',
#  'Sand tiger shark',
#  "12' shark",
# ...

# %%
# Add 'Unknown' value to empty rows 
clean_species_df['Species'].fillna('Unknown', inplace = True)
# Remove rows with no shark involvement
clean_species_df = clean_species_df[clean_species_df.Species != 'Shark involvement unconfirmed but considered probable']
clean_species_df = clean_species_df[clean_species_df.Species != 'Shovelnose "shark" which is a ray, not a shark)']
clean_species_df = clean_species_df[clean_species_df.Species != 'Reported as shark bite but injury caused by stingray']
clean_species_df = clean_species_df[clean_species_df.Species != 'Reported as shark attacks but injuries caused by toadfish']
clean_species_df = clean_species_df[clean_species_df.Species != 'Injury most likely caused by barracuda, not a shark']
clean_species_df = clean_species_df[clean_species_df.Species != 'Shark involvement not confirmed']
clean_species_df = clean_species_df[clean_species_df.Species != 'Shark invovlement not confirmed']
clean_species_df = clean_species_df[clean_species_df.Species != 'Shark involvement unconfirmed']
clean_species_df = clean_species_df[clean_species_df.Species != 'Injury believed caused by an eel, not a shark']
clean_species_df = clean_species_df[clean_species_df.Species != 'No shark invovlement']
clean_species_df = clean_species_df[clean_species_df.Species != 'Shark involvement prior to death not confirmed']
clean_species_df = clean_species_df[clean_species_df.Species != 'Shark involvement questionable']
clean_species_df = clean_species_df[clean_species_df.Species != 'Shark involvement highly doubtful']
clean_species_df = clean_species_df[clean_species_df.Species != 'Shark involvement not cofirmed']
clean_species_df = clean_species_df[clean_species_df.Species != 'No shark invovlement - it ws a publicity stunt']
clean_species_df = clean_species_df[clean_species_df.Species != "Said to involve an 8' shark but more likely damage caused by debris"]
clean_species_df = clean_species_df[clean_species_df.Species != 'Death may have been due to drowning']
clean_species_df = clean_species_df[clean_species_df.Species != "Thought to involve a 3' to 4' shark, but shark involvement not confirmed"]
clean_species_df = clean_species_df[clean_species_df.Species != 'Shark involvement prior to death still to be determined']
clean_species_df = clean_species_df[clean_species_df.Species != 'Shark involvement not confirmed & highly unlikely']
clean_species_df = clean_species_df[clean_species_df.Species != 'Salmon shark suspected, but unlikely']
clean_species_df = clean_species_df[clean_species_df.Species != 'Shark involvement prior to death was not confirmed']
clean_species_df = clean_species_df[clean_species_df.Species != 'Reported by media as shark attack, but shark involvement prior to death was not confirmed']
clean_species_df = clean_species_df[clean_species_df.Species != 'Shark involvement not confirmed; thought to be a barracuda bite']
clean_species_df = clean_species_df[clean_species_df.Species != 'Not a shark attack; it was a hoax']
clean_species_df = clean_species_df[clean_species_df.Species != 'Questionable Incident']
clean_species_df = clean_species_df[clean_species_df.Species != 'Questionable incident']
clean_species_df = clean_species_df[clean_species_df.Species != 'Questionable']
clean_species_df = clean_species_df[clean_species_df.Species != "Mr. Burgess of ISAF announced the injury was the bite of a 1.8 m [6'], 2- to 3-year old white shark. Subsequent investigation revealed there was no shark involvement in this incident"]
clean_species_df = clean_species_df[clean_species_df.Species != 'shark involvement not confirmed']
clean_species_df = clean_species_df[clean_species_df.Species != 'Shark involvement probable, but not confirmed']
clean_species_df = clean_species_df[clean_species_df.Species != 'Shark involvement not confirmed, injury may have been caused by a bluefish']
clean_species_df = clean_species_df[clean_species_df.Species != 'Shark involvement not confirmed, injury may be due to a stingray']
clean_species_df = clean_species_df[clean_species_df.Species != 'Shark involvement prior to death unconfired']
clean_species_df = clean_species_df[clean_species_df.Species != 'Questionable incident - shark bite may have precipitated drowning']
clean_species_df = clean_species_df[clean_species_df.Species != 'Shark involvement prior to death suspected but not confirmed']
clean_species_df = clean_species_df[clean_species_df.Species != 'Shark involvement prior to death could not be determined']
clean_species_df = clean_species_df[clean_species_df.Species != 'Shark involvement suspected but not confirmed']
clean_species_df = clean_species_df[clean_species_df.Species != 'Doubtful / Unconfirmed attack / Unable to verify in local records']
clean_species_df = clean_species_df[clean_species_df.Species != 'Shark involvement not confirmed; officials considered barracua']
clean_species_df = clean_species_df[clean_species_df.Species != 'Questionable incident; reported as shark attack but thought to involve a pinniped instead']
clean_species_df = clean_species_df[clean_species_df.Species != 'Reported as a shark attack, the story was a hoax']
clean_species_df = clean_species_df[clean_species_df.Species != 'Considered a "Doubtful" incident']
clean_species_df = clean_species_df[clean_species_df.Species != 'Shark involvement prior to death remains unconfirmed']
clean_species_df = clean_species_df[clean_species_df.Species != 'Shark involvement doubtful']
clean_species_df = clean_species_df[clean_species_df.Species !='Not authenticated']
clean_species_df = clean_species_df[clean_species_df.Species != 'Invalid incident']
clean_species_df = clean_species_df[clean_species_df.Species != 'Invalid']
clean_species_df = clean_species_df[clean_species_df.Species != "Questionable incident, said to involve a 6' shark"]
clean_species_df = clean_species_df[clean_species_df.Species != 'Shark involvement prior to death unconfirmed']
clean_species_df = clean_species_df[clean_species_df.Species != 'Dooley believed his Injury was caused by stingray (Dasyatidae family)']
clean_species_df = clean_species_df[clean_species_df.Species != 'According to Benjamin, the injury was inflicted by a barracuda, not a shark']
clean_species_df = clean_species_df[clean_species_df.Species != 'Shark involvement prior to deaths was not confirmed']
clean_species_df = clean_species_df[clean_species_df.Species != 'No shark involvement']
clean_species_df = clean_species_df[clean_species_df.Species != 'Description of shark does not ring true']
clean_species_df = clean_species_df[clean_species_df.Species != '2\' "banjo shark"']
shark_attack_df = clean_species_df[clean_species_df.Species != 'Said to involve a white shark but shark involvement not confirmed']
shark_attack_df
# Out:
#       index   Case Number                  Date    Year        Type  \
# 0         0    2020.02.05              5-Feb-20  2020.0  Unprovoked
# 1         1  2020.01.30.R  Reported 30-Jan-2020  2020.0    Provoked
# 2         2    2020.01.17             17-Jan-20  2020.0  Unprovoked
# 3         3    2020.01.16             16-Jan-20  2020.0  Unprovoked
# 4         4    2020.01.13             13-Jan-20  2020.0  Unprovoked
# ...     ...           ...                   ...     ...         ...
# 6457   6457       ND.0005           Before 1903     0.0  Unprovoked
# 6458   6458       ND.0004           Before 1903     0.0  Unprovoked
# 6459   6459       ND.0003             1900-1905     0.0  Unprovoked
# 6460   6460       ND.0002             1883-1889     0.0  Unprovoked
# 6461   6461       ND.0001             1845-1853     0.0  Unprovoked
#
#                  Country               Area  \
# 0                    USA               Maui
# 1                BAHAMAS             Exumas
# ...

# %%
# Make questionable columns 'Unknown'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bor\b', case = 'false', regex = 'true'), 'Species'] = 'Unknown'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bpossibly\b', case = 'false'), 'Species'] = 'Unknown'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bPossibly\b', case = 'false'), 'Species'] = 'Unknown'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bPossibily\b', case = 'false'), 'Species'] = 'Unknown'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bunidentified\b', case = 'false'), 'Species'] = 'Unknown'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bUnidentified\b', case = 'false'), 'Species'] = 'Unknown'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bquestionable\b', case = 'false'), 'Species'] = 'Unknown'
shark_attack_df.loc[shark_attack_df['Species'] == '"grey shark"', 'Species'] = 'Unknown'
shark_attack_df.loc[shark_attack_df['Species'] == '"grey-colored shark"', 'Species'] = 'Unknown'
shark_attack_df.loc[shark_attack_df['Species'] == '1.8 m grey shark', 'Species'] = 'Unknown'
shark_attack_df.loc[shark_attack_df['Species'] == "1.8 m [6'] grey-colored shark", 'Species'] = 'Unknown'
shark_attack_df.loc[shark_attack_df['Species'] == "2.4 m to 3 m [8' to 10'] grey colored shark", 'Species'] = 'Unknown'
shark_attack_df.loc[shark_attack_df['Species'] == '1.2 m [4\'] "grey-colored shark"', 'Species'] = 'Unknown'
shark_attack_df.loc[shark_attack_df['Species'] == '"gray shark"', 'Species'] = 'Unknown'
shark_attack_df.loc[shark_attack_df['Species'] =='1 m "grey-colored" shark'] = 'Unknown'

# %%
# Group species by sinlge name identifier 
# Sand tiger/ grey nurse/ ragged-tooth shark
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bSandtiger\b', case = 'false'), 'Species'] = 'Sand_Tiger'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bsandtiger\b', case = 'false'), 'Species'] = 'Sand_Tiger'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bSand\b', case = 'false'), 'Species'] = 'Sand_Tiger'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bsand\b', case = 'false'), 'Species'] = 'Sand_Tiger'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bRaggedtooth\b', case = 'false'), 'Species'] = 'Sand_Tiger'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bsandshark\b', case = 'false'), 'Species'] = 'Sand_Tiger'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bnurse\b', case = 'false'), 'Species'] = 'Sand_Tiger'
# Tiger shark
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bTiger\b', case = 'false'), 'Species'] = 'Tiger'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\btiger\b', case = 'false'), 'Species'] = 'Tiger'
# Lemon shark
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bLemon\b', case = 'false'), 'Species'] = 'Lemon'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\blemon\b', case = 'false'), 'Species'] = 'Lemon'
# Broad nose seven gill/ cow shark 
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bBroadnose\b', case = 'false'), 'Species'] = 'Broad_Nose_Seven_Gill'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bCow\b', case = 'false'), 'Species'] = 'Broad_Nose_Seven_Gill'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\b7-gill\b', case = 'false'), 'Species'] = 'Broad_Nose_Seven_Gill'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\Sevengill\b', case = 'false'), 'Species'] = 'Broad_Nose_Seven_Gill'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bcow\b', case = 'false'), 'Species'] = 'Broad_Nose_Seven_Gill'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bSeven-gill\b', case = 'false'), 'Species'] = 'Broad_Nose_Seven_Gill'
# Cookiecutter shark 
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bCookiecutter\b', case = 'false'), 'Species'] = 'Cookiecutter'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bcookie\b', case = 'false'), 'Species'] = 'Cookiecutter'
# Spinner shark
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bSpinner\b', case = 'false'), 'Species'] = 'Spinner'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bspinner\b', case = 'false'), 'Species'] = 'Spinner'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bmaculipinnis\b', case = 'false'), 'Species'] = 'Spinner'
# Tawny nurse shark
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bTawny\b', case = 'false'), 'Species'] = 'Tawny_Nurse'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bTawney\b', case = 'false'), 'Species'] = 'Tawny_Nurse'
# Porbeagle shark 
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bPorbeagle\b', case = 'false'), 'Species'] = 'Porbeagle'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bporbeagle\b', case = 'false'), 'Species'] = 'Porbeagle'
# Bull/ Zambezi shark
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bBull\b', case = 'false'), 'Species'] = 'Bull'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bbull\b', case = 'false'), 'Species'] = 'Bull'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bZambesi\b', case = 'false'), 'Species'] = 'Bull'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bZambezi\b', case = 'false'), 'Species'] = 'Bull'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bleucas\b', case = 'false'), 'Species'] = 'Bull'
# Wobbegong shark family
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bWobbegong\b', case = 'false'), 'Species'] = 'Unspecified_Wobbegong'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bWobbegongs\b', case = 'false'), 'Species'] = 'Unspecified_Wobbegong'
# Copper/ Bronze whaler shark 
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bBronze\b', case = 'false'), 'Species'] = 'Copper'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bCopper\b', case = 'false'), 'Species'] = 'Copper'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bwhaler\b', case = 'false'), 'Species'] = 'Copper'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bcopper\b', case = 'false'), 'Species'] = 'Copper'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bmacrurus\b', case = 'false'), 'Species'] = 'Copper'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bWhaler\b', case = 'false'), 'Species'] = 'Copper'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bcocktail\b', case = 'false'), 'Species'] = 'Copper'
# Short fin mako/ blue point sharks
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bpointers\b', case = 'false'), 'Species'] = 'Shortfin_Mako'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bShortfin\b', case = 'false'), 'Species'] = 'Shortfin_Mako'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bpointer\b', case = 'false'), 'Species'] = 'Shortfin_Mako'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bBonita\b', case = 'false'), 'Species'] = 'Shortfin_Mako'
# Long fin mako
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bLongfin\b', case = 'false'), 'Species'] = 'Longfin_Mako'
# Mako shark genus 
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bMako\b', case = 'false'), 'Species'] = 'Unspecified_Mako'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bmako\b', case = 'false'), 'Species'] = 'Unspecified_Mako'
# Shovelnose shark
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bShovelnose\b', case = 'false'), 'Species'] = 'Shovelnose'
# Dusky reef shark
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bdusky\b', case = 'false'), 'Species'] = 'Dusky_Reef'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bDusky\b', case = 'false'), 'Species'] = 'Dusky_Reef'
# Galapagos reef shark
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bGalapagos\b', case = 'false'), 'Species'] = 'Galapagos_Reef'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bGalapagos_reef\b', case = 'false'), 'Species'] = 'Galapagos_Reef'
# Sandbar/ Brown shark 
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bSandbar\b', case = 'false'), 'Species'] = 'Sandbar'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bsandbar\b', case = 'false'), 'Species'] = 'Sandbar'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bbrown\b', case = 'false'), 'Species'] = 'Sandbar'
# Horn shark
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bHorn\b', case = 'false'), 'Species'] = 'Horn'
# Silky shark
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bSilky\b', case = 'false'), 'Species'] = 'Silky'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bsilky\b', case = 'false'), 'Species'] = 'Silky'

# Goblin shark
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bGoblin\b', case = 'false'), 'Species'] = 'Goblin'
# Whale shark
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bWhale\b', case = 'false'), 'Species'] = 'Whale'
# Thresher shark genus
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bthresher\b', case = 'false'), 'Species'] = 'Unspecified_Thresher'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bThresher\b', case = 'false'), 'Species'] = 'Unspecified_Thresher'
# Port Jackson shark 
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bJackson\b', case = 'false'), 'Species'] = 'Port_Jackson'
# Great blue shark
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bBlue\b', case = 'false'), 'Species'] = 'Blue'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bblue\b', case = 'false'), 'Species'] = 'Blue'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bBlue\b', case = 'false'), 'Species'] = 'Great_Blue'
# Silvertip reef shark
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bsilvertip\b', case = 'false'), 'Species'] = 'Silvertip_Reef'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bSilvertip\b', case = 'false'), 'Species'] = 'Silvertip_Reef'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\balbimarginatus\b', case = 'false'), 'Species'] = 'Silvertip_Reef'
# Salmon shark 
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bSalmon\b', case = 'false'), 'Species'] = 'Salmon'
# Caribbean reef shark
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bCaribbean\b', case = 'false'), 'Species'] = 'Caribbean_Reef'
# Soupfin shark
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bSoupfin\b', case = 'false'), 'Species'] = 'Soupfin'
# Angel shark genus
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bAngel\b', case = 'false'), 'Species'] = 'Unspecified_Angel'
# Sandy dogfish shark
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bcanicula\b', case = 'false'), 'Species'] = 'Sandy_dogfish'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bSandy_dogfish\b', case = 'false'), 'Species'] = 'Sandy_Dogfish'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bdogfish\b', case = 'false'), 'Species'] = 'Sandy_Dogfish'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bDog\b', case = 'false'), 'Species'] = 'Sandy_Dogfish'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bdog\b', case = 'false'), 'Species'] = 'Sandy_Dogfish'
# Basking shark
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bBasking\b', case = 'false'), 'Species'] = 'Basking'
# Hammerhead shark family
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bhammerhead\b', case = 'false'), 'Species'] = 'Unspecified_Hammerhead'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bHammerhead\b', case = 'false'), 'Species'] = 'Unspecified_Hammerhead'
# Spudog shark genus 
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bSpurdog\b', case = 'false'), 'Species'] = 'Unspecified_Spurdog'
# Catshark shark family
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bcatsharks\b', case = 'false'), 'Species'] = 'Catshark'
# Starry smoothhound shark 
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bStarry\b', case = 'false'), 'Species'] = 'Starry_Smoothhound'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bhound\b', case = 'false'), 'Species'] = 'Starry_Smoothhound'
# Leopard shark
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bLeopard\b', case = 'false'), 'Species'] = 'Leopard'
# Oceanic whitetip shark 
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bOceanic\b', case = 'false'), 'Species'] = 'Oceanic_Whitetip'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\boceanic\b', case = 'false'), 'Species'] = 'Oceanic_Whitetip'
# Nurse shark
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bNurse\b', case = 'false'), 'Species'] = 'Nurse'
# Great white shark 
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bWhite\b', case = 'false'), 'Species'] = 'Great_White'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bwhite\b', case = 'false'), 'Species'] = 'Great_White'
# Whitetip reef shark
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bWhitetip\b', case = 'false'), 'Species'] = 'Whitetip_Reef'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bWhtietip\b', case = 'false'), 'Species'] = 'Whitetip_Reef'
# Carpet shark family
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bCarpet\b', case = 'false'), 'Species'] = 'Unspecified_Carpet'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bcarpet\b', case = 'false'), 'Species'] = 'Unspecified_Carpet'
# Ground shark order
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bground\b', case = 'false'), 'Species'] = 'Unspecified_Ground'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bcarcharhinid\b', case = 'false'), 'Species'] = 'Unspecified_Ground'
# Ganges shark
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bgangeticus\b', case = 'false'), 'Species'] = 'Ganges'
# Grey reef shark
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bGrey\b', case = 'false'), 'Species'] = 'Grey_Reef'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bgrey\b', case = 'false'), 'Species'] = 'Grey_Reef'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bGray\b', case = 'false'), 'Species'] = 'Grey_Reef'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bgray\b', case = 'false'), 'Species'] = 'Grey_Reef'
# Reef shark family 
shark_attack_df.loc[shark_attack_df['Species'] == '1.2 m to 1.5 m [4\' to 5\'] "reef shark"', 'Species'] = 'Unspecified_Reef'
shark_attack_df.loc[shark_attack_df['Species'] == "2.1 m [7'], 140-lb reef shark", 'Species'] = 'Unspecified_Reef'
shark_attack_df.loc[shark_attack_df['Species'] == "2' to 3' reef shark", 'Species'] = 'Unspecified_Reef'
shark_attack_df.loc[shark_attack_df['Species'] == 'reef shark, 1.8m', 'Species'] = 'Unspecified_Reef'
shark_attack_df.loc[shark_attack_df['Species'] == 'a small reef shark', 'Species'] = 'Unspecified_Reef'
shark_attack_df.loc[shark_attack_df['Species'] == 'reef shark, 1.5m', 'Species'] = 'Unspecified_Reef'
shark_attack_df.loc[shark_attack_df['Species'] == 'reef shark', 'Species'] = 'Unspecified_Reef'
shark_attack_df.loc[shark_attack_df['Species'] == 'reef shark, 1m', 'Species'] = 'Unspecified_Reef'
shark_attack_df.loc[shark_attack_df['Species'] == '"reef shark"', 'Species'] = 'Unspecified_Reef'
shark_attack_df.loc[shark_attack_df['Species'] == 'Reef shark x 2', 'Species'] = 'Unspecified_Reef'
shark_attack_df.loc[shark_attack_df['Species'] == "Reef shark, 5'", 'Species'] = 'Unspecified_Reef'
shark_attack_df.loc[shark_attack_df['Species'] == 'reef shark?', 'Species'] = 'Unspecified_Reef'
#Blacktip reef shark
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\breef\b', case = 'false'), 'Species'] = 'Blacktip_Reef'
# Oceanic Blacktip shark
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bBlacktip\b', case = 'false'), 'Species'] = 'Oceanic_Blacktip'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bblacktip\b', case = 'false'), 'Species'] = 'Oceanic_Blacktip'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bblack-tipped\b', case = 'false'), 'Species'] = 'Oceanic_Blacktip'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bBlackfin\b', case = 'false'), 'Species'] = 'Oceanic_Blacktip'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\btipped\b', case = 'false'), 'Species'] = 'Oceanic_Blacktip'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bfinned\b', case = 'false'), 'Species'] = 'Oceanic_Blacktip'
shark_attack_df.loc[shark_attack_df['Species'].str.contains(r'\bblackfin\b', case = 'false'), 'Species'] = 'Oceanic_Blacktip'

# %%
# Set reaming values to "Unknown"
species_list = ["Sand_Tiger", "Tiger", "Lemon", "Broad_Nose_Seven_Gill", "Cookiecutter", "Spinner", "Tawny_Nurse",
               "Porbeagle", "Bull", "Unspecified_Wobbegong", "Copper", "Shortfin_Mako", "Longfin_Mako", "Unspecified_Mako",
               "Shovelnose", "Dusky_Reef", "Galapagos_Reef", "Sandbar", "Horn", "Silky", "Goblin", "Whale", "Unspecified_Thresher",
               "Port_Jackson", "Great_Blue", "Silvertip_Reef", "Salmon", "Caribbean_Reef", "Soupfin", "Unspecified_Angel",
               "Sandy_Dogfish","Basking", "Unspecified_Hammerhead", "Unspecified_Spurdog", "Catshark", "Starry_Smoothhound",
               "Leopard", "Oceanic_Whitetip", "Nurse", "Great_White", "Whitetip_Reef", "Unspecified_Carpet", "Unspecified_Ground",
               "Ganges", "Grey_Reef", "Unspecified_Reef", "Blacktip_Reef", "Oceanic_Blacktip", "Unknown"]
shark_attack_df_copy = shark_attack_df.copy()
shark_attack_df_copy

for row in shark_attack_df_copy.Species:
    if row not in species_list:
        row = 'Unknown'
    
list(shark_attack_df_copy.Species.unique())
# Out:
# ['Tiger',
#  'Unknown',
#  '"A small shark"',
#  'Broad_Nose_Seven_Gill',
#  'Lemon',
#  'Great_White',
#  'Oceanic_Blacktip',
#  "4' to 5' shark",
#  'Oceanic_Whitetip',
#  "7' shark",
#  'Juvenile shark',
#  '1+ m shark',
#  "6' to 7' shark",
#  "2' shark",
#  'Nurse',
#  "6.5' shark",
#  "10' to 12' shark",
#  'Sand_Tiger',
#  'shark pup',
#  'Bull',
#  "8' shark",
#  'Cookiecutter',
#  "12' shark",
#  'Grey_Reef',
#  "4' shark",
#  'Spinner',
#  '2.5 m shark',
#  'Unspecified_Wobbegong',
#  'Unspecified_Mako',
#  'Copper',
#  'Unspecified_Reef',
#  "5' shark",
#  "3' to 4' shark",
#  'Salmon',
#  '2 m shark',
#  '3 m shark',
#  "6' shark",
#  '3.5 m shark',
#  '1.8 m shark',
#  'Galapagos_Reef',
#  '2m shark',
#  'small shark',
#  'Great_Blue',
#  'Porbeagle',
#  "5' to 6' shark",
#  'A small shark',
#  'Starry_Smoothhound',
#  "3' shark",
#  "9' shark",
#  "10' shark",
#  'Caribbean_Reef',
#  'a small shark',
#  "6' to 8' shark",
#  'Unspecified_Angel',
#  'Sandy_Dogfish',
# ...

# %%
#data_df.to_csv("shark_data.csv", index=False
